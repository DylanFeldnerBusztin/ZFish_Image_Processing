# %%
# Registering high resolution image to the HLAVL template

# %%
import ants
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
# Machine specific setup of folder names
#-------------------------------------------------------------------------------------------------
import getpass
if getpass.getuser() == 'roschkoenig':
    Fimg = '/Users/roschkoenig/Dropbox/Research/1805 Seizure segment/Dylan Registration/Zebrafish'
    fipath = Fimg + os.sep + 'Elavl3-H2BRFP.tif'
    mopath = Fimg + os.sep + 'Substack_Red_large.tif'
else:
    fipath = '/home/dylan/Elavl3-H2BRFP.tif'
    mopath = '/home/dylan/Desktop/Lab/Substack_Red_large.tif'

# %%
# Prepare template
fi = ants.image_read(fipath)
mo = ants.image_read(mopath)

# %%
ants.plot(mo, axis = 2, slices = range(8))

# %%
your_fish_looks = 'L'  # 'L'eft, 'R'ight, 'U'p, 'D'own

# %%
fi.set_spacing(list([0.8, 0.8,2.0]))
mo.set_spacing(list([.3,.3, 8]))

if your_fish_looks == 'L':
    mo.set_direction(np.array([[-1.,0.,0.],[0.,1.,0.],[0.,0.,1.]]))
    mo.set_origin((750,0,100))

# %%
ants.plot(fi, mo, overlay_cmap = 'magma', overlay_alpha=.7,axis = 2, slices = [10*x+50 for x in range(8)])

# %%
ants.image_physical_space_consistency(fi, mo) # Left this in especially for Dylan
# Out:
# False

# %%
# Rigid
mrtr_r = ants.registration(fi, mo, type_of_transforms = 'Rigid')
mr_r   = ants.apply_transforms(fi, mo, transformlist=mrtr_r['fwdtransforms'])

# %%
ants.plot(fi, mr_r, overlay_cmap = 'magma', overlay_alpha=.7,axis = 2, slices = [10*x+50 for x in range(8)])

# %%
# Syn registration starting from rigid transform
#---------------------------------------------------------------------------------
mrtr_s = ants.registration(ref, mimg, type_of_transforms = 'Syn')
mr_s   = ants.apply_transforms(ref, mimg, transformlist = mrtr_s['fwdtransforms'])
